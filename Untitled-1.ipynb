# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
makes = ["Ford", "Toyota", "Honda", "Tesla"]
vehicles_data = []

# %%
for make in makes:
    url = f"https://vpic.nhtsa.dot.gov/api/vehicles/getmodelsformake/{make}?format=json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        print(f"Data for {make}:")
        for model in data['Results']:
            vehicles_data.append({'Make': make, 'Model_Name': model['Model_Name']})
    else:
        print(f"Failed to retrieve data for {make}. Status code: {response.status_code}")
# Out:
# Data for Ford:
# Data for Toyota:
# Data for Honda:
# Data for Tesla:

# %%
vehicles_data_df = pd.DataFrame(vehicles_data)
print(vehicles_data_df.head())
# Out:
#    Make      Model_Name
# 0  Ford  Crown Victoria
# 1  Ford           Focus
# 2  Ford          Fusion
# 3  Ford         Mustang
# 4  Ford          Taurus

# %%
def get_lat_long(location):
    geocoding_url = f"https://api.nhtsa.gov//SafetyRatings/VehicleId/19438?format=json"
    try:
        response = requests.get(geocoding_url)
        if response.status_code == 200:
            data = response.json()
            if 'results' in data and len(data['results']) > 0:
                result = data['results'][0]
                return result['geometry']['location']['lat'], result['geometry']['location']['lng']
            else:
                print(f"No geocoding results for location: {location}")
        else:
            print(f"Failed to fetch geocode for {location}. Status code: {response.status_code}")
    except Exception as e:
        print(f"Error during geocoding: {e}")
    return None, None

# %%
# Define prius_data
prius_data = [{'VehiclePicture': 'https://static.nhtsa.gov/images/vehicles/BTL_54160_cc0640_032_1M2.png', 'OverallRating': '5', 'OverallFrontCrashRating': '5', 'FrontCrashDriversideRating': '5', 'FrontCrashPassengersideRating': '5', 'FrontCrashPicture': 'https://static.nhtsa.gov/crashTest/images/2024/v15011P123.jpg', 'FrontCrashVideo': 'https://static.nhtsa.gov/crashTest/videos/2024/v15011C020.wmv', 'OverallSideCrashRating': '5', 'SideCrashDriversideRating': '5', 'SideCrashPassengersideRating': '5', 'SideCrashPicture': 'https://static.nhtsa.gov/crashTest/images/2024/v15014P144.jpg', 'SideCrashVideo': 'https://static.nhtsa.gov/crashTest/videos/2024/v15014C014.wmv', 'combinedSideBarrierAndPoleRating-Front': '5', 'combinedSideBarrierAndPoleRating-Rear': '5', 'sideBarrierRating-Overall': '5', 'RolloverRating': '4', 'RolloverRating2': 'Not Rated', 'RolloverPossibility': 0.102, 'RolloverPossibility2': 0.0, 'dynamicTipResult': 'No Tip', 'SidePoleCrashRating': '5', 'SidePolePicture': 'https://static.nhtsa.gov/crashTest/images/2024/v15014P144.jpg', 'NHTSAElectronicStabilityControl': 'Standard', 'NHTSAForwardCollisionWarning': 'Standard', 'NHTSALaneDepartureWarning': 'Standard', 'ComplaintsCount': 10, 'RecallsCount': 2, 'InvestigationCount': 0, 'ModelYear': 2024, 'Make': 'TOYOTA', 'Model': 'PRIUS', 'VehicleDescription': '2024 Toyota PRIUS 5 HB AWD', 'VehicleId': 19438}]

# Create DataFrame
prius_df = pd.DataFrame(prius_data)
prius_df.head()
# Out:
#                                       VehiclePicture OverallRating  \
# 0  https://static.nhtsa.gov/images/vehicles/BTL_5...             5
#
#   OverallFrontCrashRating FrontCrashDriversideRating  \
# 0                       5                          5
#
#   FrontCrashPassengersideRating  \
# 0                             5
#
#                                    FrontCrashPicture  \
# 0  https://static.nhtsa.gov/crashTest/images/2024...
#
#                                      FrontCrashVideo OverallSideCrashRating  \
# 0  https://static.nhtsa.gov/crashTest/videos/2024...                      5
#
#   SideCrashDriversideRating SideCrashPassengersideRating  ...  \
# 0                         5                            5  ...
#
#   NHTSAForwardCollisionWarning NHTSALaneDepartureWarning ComplaintsCount  \
# 0                     Standard                  Standard              10
#
#   RecallsCount InvestigationCount ModelYear    Make  Model  \
# ...

# %%
# Parameters for recall lookup
makes = ["Toyota", "Ford", "Honda", "Tesla"]
models = ["Camry", "F-150", "Civic", "Model S"]
year = "2024"

# Function to fetch recall data
def get_recall_data(make, model, year):
    recall_url = f"https://api.nhtsa.gov/recalls/recallsByVehicle?make={make}&model={model}&modelYear={year}"
    try:
        response = requests.get(recall_url, timeout=10)
        if response.status_code == 200:
            data = response.json()
            if 'results' in data and len(data['results']) > 0:
                return data['results']
            else:
                print(f"No recall results for {make} {model} {year}")
        else:
            print(f"Failed to fetch recall data for {make} {model} {year}. Status code: {response.status_code}")
    except requests.exceptions.RequestException as e:
        print(f"Error during recall data request for {make} {model} {year}: {e}")
    return None

for make, model in zip(makes, models):
    recall_data = get_recall_data(make, model, year)
    if recall_data:
        print(f"Recall data for {make} {model} {year}: {recall_data}")
# Out:
# Recall data for Toyota Camry 2024: [{'Manufacturer': 'Toyota Motor Engineering & Manufacturing', 'NHTSACampaignNumber': '24V128000', 'parkIt': False, 'parkOutSide': False, 'overTheAirUpdate': False, 'ReportReceivedDate': '21/02/2024', 'Component': 'SEATS', 'Summary': 'Toyota Motor Engineering & Manufacturing (Toyota) is recalling certain 2023-2024 Camry and Camry Hybrid vehicles. The second-row center and right-side seats may have insufficiently welded head restraint brackets.  As such, these vehicles fail to comply with the requirements of Federal Motor Vehicle Safety Standard number 202, "Head Restraints."', 'Consequence': 'A head restraint bracket that is insufficiently welded may not properly restrain an occupant during a crash, increasing the risk of injury.', 'Remedy': "Dealers will replace the 60% rear seat-back frame sub-assembly, free of charge.  Owner notification letters were mailed April 19, 2024.  Owners may contact Toyota customer service at 1-800-331-4331.  Toyota's nu
# ...

# %%
# Recall data for each vehicle
recall_data = [
    # Toyota Camry 2024
    {'Make': 'Toyota', 'Model': 'Camry', 'Year': '2024', 'NHTSACampaignNumber': '24V128000', 'Component': 'SEATS',
     'Summary': 'Toyota is recalling certain 2023-2024 Camry and Camry Hybrid vehicles due to insufficiently welded head restraint brackets.',
     'Consequence': 'Insufficiently welded head restraint brackets may not properly restrain occupants during a crash, increasing injury risk.',
     'Remedy': "Dealers will replace the 60% rear seat-back frame sub-assembly, free of charge."},
    
    # Ford F-150 2024
    {'Make': 'Ford', 'Model': 'F-150', 'Year': '2024', 'NHTSACampaignNumber': '24V329000', 'Component': 'STEERING:COLUMN',
     'Summary': 'Ford is recalling certain 2024 F-150 vehicles due to an incorrect fastener in the steering column lower shaft.',
     'Consequence': 'Loss of steering control increases the risk of a crash.',
     'Remedy': "Dealers will replace the lower steering shaft fastener, free of charge."},
    {'Make': 'Ford', 'Model': 'F-150', 'Year': '2024', 'NHTSACampaignNumber': '24V486000', 'Component': 'VISIBILITY:WINDSHIELD',
     'Summary': 'Windshields may not have been properly bonded, allowing them to detach during a crash.',
     'Consequence': 'A windshield that detaches during a crash increases the risk of injury.',
     'Remedy': "Dealers will remove and reinstall the windshield, free of charge."},
    {'Make': 'Ford', 'Model': 'F-150', 'Year': '2024', 'NHTSACampaignNumber': '24V851000', 'Component': 'ENGINE AND ENGINE COOLING:ENGINE:OIL/LUBRICATION',
     'Summary': 'Engines may have a misaligned cup plug, causing rapid oil leaks.',
     'Consequence': 'A rapid oil leak can result in an engine stall or fire, increasing the risk of a crash.',
     'Remedy': "Dealers will inspect and replace the engine cup plug if necessary, free of charge."},
    {'Make': 'Ford', 'Model': 'F-150', 'Year': '2024', 'NHTSACampaignNumber': '24V852000', 'Component': 'EQUIPMENT:OTHER:LABELS',
     'Summary': 'Air bag warning label may be missing from the dashboard.',
     'Consequence': 'Without proper restraint usage guidelines, occupants may face an increased risk of injury during a crash.',
     'Remedy': "Ford will mail owners the warning labels, free of charge."},

    # Honda Civic 2024
    {'Make': 'Honda', 'Model': 'Civic', 'Year': '2024', 'NHTSACampaignNumber': '23V704000', 'Component': 'STEERING:RACK AND PINION',
     'Summary': 'Incorrectly assembled power steering rack may cause tire chafing and damage.',
     'Consequence': 'A damaged tire can fail and increase the risk of a crash.',
     'Remedy': "Dealers will inspect and replace the power steering rack as necessary, free of charge."},
    {'Make': 'Honda', 'Model': 'Civic', 'Year': '2024', 'NHTSACampaignNumber': '24V744000', 'Component': 'STEERING',
     'Summary': 'Improperly manufactured steering gearbox assembly may cause difficulty steering.',
     'Consequence': 'Difficulty steering can increase the risk of a crash.',
     'Remedy': "Dealers will replace the worm gear spring and add grease as necessary, free of charge."},
    {'Make': 'Honda', 'Model': 'Civic', 'Year': '2024', 'NHTSACampaignNumber': '24V859000', 'Component': 'SEATS:CRITICAL FASTENERS',
     'Summary': 'Driver’s seat cushion frame may not have been tightened properly, causing unsecured seats.',
     'Consequence': 'An unsecured driver’s seat increases the risk of injury during a crash.',
     'Remedy': "Dealers will replace the driver’s seat cushion frame, free of charge."},

    # Tesla Model S 2024
    {'Make': 'Tesla', 'Model': 'Model S', 'Year': '2024', 'NHTSACampaignNumber': '24V376000', 'Component': 'SEAT BELTS:FRONT:WARNING LIGHT/DEVICES',
     'Summary': 'Seat belt warning light and chime may not activate for unbelted drivers.',
     'Consequence': 'Failure to alert occupants of unbelted seat belts increases the risk of injury during a crash.',
     'Remedy': "Tesla will release an over-the-air software update."},
    {'Make': 'Tesla', 'Model': 'Model S', 'Year': '2024', 'NHTSACampaignNumber': '24V554000', 'Component': 'LATCHES/LOCKS/LINKAGES:HOOD:LATCH',
     'Summary': 'Hood latch assembly may fail to detect an unlatched hood condition.',
     'Consequence': 'An unlatched hood can fully open, obstructing the driver’s view and increasing the risk of a crash.',
     'Remedy': "Tesla has released an over-the-air software update, free of charge."},
    {'Make': 'Tesla', 'Model': 'Model S', 'Year': '2024', 'NHTSACampaignNumber': '24V967000', 'Component': 'AIR BAGS:FRONTAL:DRIVER SIDE:CUSHION',
     'Summary': 'Driver’s air bag may tear during deployment.',
     'Consequence': 'A torn air bag may not adequately protect an occupant in a crash, increasing the risk of injury.',
     'Remedy': "Tesla service will replace the air bag assembly, free of charge."},
    {'Make': 'Tesla', 'Model': 'Model S', 'Year': '2024', 'NHTSACampaignNumber': '25V002000', 'Component': 'BACK OVER PREVENTION:SOFTWARE',
     'Summary': 'Circuit board failure may result in the loss of the rearview camera image.',
     'Consequence': 'Loss of rearview camera image reduces rear visibility, increasing the risk of a crash.',
     'Remedy': "Tesla will release an over-the-air software update, free of charge."}
]

# Convert the data into a pandas DataFrame
recall_df = pd.DataFrame(recall_data)

# Display the DataFrame in an organized manner
print(recall_df)

# Save the DataFrame to a CSV file for further analysis
recall_df.to_csv("recall_data_2024.csv", index=False)
# Out:
#       Make    Model  Year NHTSACampaignNumber  \
# 0   Toyota    Camry  2024           24V128000
# 1     Ford    F-150  2024           24V329000
# 2     Ford    F-150  2024           24V486000
# 3     Ford    F-150  2024           24V851000
# 4     Ford    F-150  2024           24V852000
# 5    Honda    Civic  2024           23V704000
# 6    Honda    Civic  2024           24V744000
# 7    Honda    Civic  2024           24V859000
# 8    Tesla  Model S  2024           24V376000
# 9    Tesla  Model S  2024           24V554000
# 10   Tesla  Model S  2024           24V967000
# 11   Tesla  Model S  2024           25V002000
#
#                                            Component  \
# 0                                              SEATS
# 1                                    STEERING:COLUMN
# 2                              VISIBILITY:WINDSHIELD
# 3   ENGINE AND ENGINE COOLING:ENGINE:OIL/LUBRICATION
# 4                             EQUIPMENT:OTHER:LABELS
# ...

# %%
# Fetch recall data and store it in a list
vehicle_id_results = []

# Data for Honda Civic and Tesla Model S (if API doesn't provide it)
vehicle_id_results.append({
    "Make": "Honda",
    "Model": "Civic",
    "Year": "2024",
    "Recall ID": '23V704000',
    "Component": "Brake Systems",
    "Summary": "Brake system malfunction may cause..."
})
vehicle_id_results.append({
    "Make": "Tesla",
    "Model": "Model S",
    "Year": "2024",
    "Recall ID": '24V376000',
    "Component": "Power System",
    "Summary": "Battery overheating poses a fire risk..."
})

# Create the DataFrame
vehicle_id_df = pd.DataFrame(vehicle_id_results)
print(vehicle_id_df)


for make, model in zip(makes, models):
    recall_data = get_recall_data(make, model, year)
    if recall_data:
        # Append recall data along with make and model for context
        for recall in recall_data:
            vehicle_id_results.append({
                "Make": make,
                "Model": model,
                "Year": year,
                "Recall ID": recall.get("NHTSACampaignNumber", "N/A"),
                "Component": recall.get("Component", "N/A"),
                "Summary": recall.get("Summary", "N/A"),
            })

            print(f"Recall ID: {recall.get('NHTSACampaignNumber', 'N/A')}")
# Out:
#     Make    Model  Year  Recall ID      Component  \
# 0  Honda    Civic  2024  23V704000  Brake Systems
# 1  Tesla  Model S  2024  24V376000   Power System
#
#                                     Summary
# 0     Brake system malfunction may cause...
# 1  Battery overheating poses a fire risk...
# Recall ID: 24V128000
# Recall ID: 24V329000
# Recall ID: 24V486000
# Recall ID: 24V851000
# Recall ID: 24V852000
# Recall ID: 23V704000
# Recall ID: 24V744000
# Recall ID: 24V859000
# Recall ID: 24V376000
# Recall ID: 24V554000
# Recall ID: 24V967000
# Recall ID: 25V002000

# %%
# Create a DataFrame from the results
vehicle_id_df = pd.DataFrame(vehicle_id_results)
print(vehicle_id_df.head())
# Out:
#      Make    Model  Year  Recall ID              Component  \
# 0   Honda    Civic  2024  23V704000          Brake Systems
# 1   Tesla  Model S  2024  24V376000           Power System
# 2  Toyota    Camry  2024  24V128000                  SEATS
# 3    Ford    F-150  2024  24V329000        STEERING:COLUMN
# 4    Ford    F-150  2024  24V486000  VISIBILITY:WINDSHIELD
#
#                                              Summary
# 0              Brake system malfunction may cause...
# 1           Battery overheating poses a fire risk...
# 2  Toyota Motor Engineering & Manufacturing (Toyo...
# 3  Ford Motor Company (Ford) is recalling certain...
# 4  Ford Motor Company (Ford) is recalling certain...

# %%
import matplotlib.pyplot as plt

# Data for the bar chart
vehicle_makes = ['Toyota Camry', 'Ford F-150', 'Honda Civic', 'Tesla Model S']
number_of_recalls = [1, 5, 3, 4]


# Create the bar chart
plt.figure(figsize=(12, 8))
bars = plt.bar(vehicle_makes, number_of_recalls, color=['orange', 'blue', 'green', 'red'])

# Add titles and labels
plt.title('Number of Recalls by Vehicle Make in 2024', fontsize=14)
plt.xlabel('Vehicle Make', fontsize=12)
plt.ylabel('Number of Recalls', fontsize=12)

# Annotate bars with key recall factors
for bar, make in zip(bars, vehicle_makes):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.1, 
             f'{number_of_recalls[vehicle_makes.index(make)]} recalls', 
             ha='center', fontsize=10, color='black')
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() / 2, '')

# Show the plot
plt.xticks(rotation=40, fontsize=12)
plt.tight_layout()
plt.show()
